# %%
import pandas as pd
import numpy as np
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
# Out:
# C:\Users\taspl\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
raw_train_dataframe = pd.read_csv("train.csv")
raw_train_dataframe.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
women = raw_train_dataframe.loc[raw_train_dataframe.Sex == 'female']['Survived']
print(sum(women)/len(women))

men = raw_train_dataframe.loc[raw_train_dataframe.Sex == 'male']['Survived']
print(sum(men)/len(men))

filt1 = raw_train_dataframe.loc[(raw_train_dataframe.Age <= 13) & (raw_train_dataframe.Sex == 'male')]
filt2 = raw_train_dataframe.loc[(raw_train_dataframe.Age <= 13) & (raw_train_dataframe.Sex == 'female')]

female_children = raw_train_dataframe.loc[(raw_train_dataframe.Age >= 60) & (raw_train_dataframe.Sex == 'female')]['Survived']
male_children = raw_train_dataframe.loc[(raw_train_dataframe.Age >= 60) & (raw_train_dataframe.Sex == 'male')]['Survived']

print(sum(female_children)/len(female_children))
print(sum(male_children)/len(male_children))
# Out:
# 0.7420382165605095
# 0.18890814558058924
# 1.0
# 0.13636363636363635

# %%
raw_train_dataframe.columns[raw_train_dataframe.isnull().any()]
# Out:
# Index(['Age', 'Cabin', 'Embarked'], dtype='object')

# %%
raw_train_dataframe.Age.mean()
# Out:
# 29.69911764705882

# %%
raw_train_dataframe[raw_train_dataframe.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
raw_test_dataframe = pd.read_csv("test.csv")
raw_test_dataframe.head(5)
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
features = ['Pclass', 'Sex', 'SibSp', 'Parch']
X_train = pd.get_dummies(raw_train_dataframe[features])
X_test = pd.get_dummies(raw_test_dataframe[features])
y_train = raw_train_dataframe['Survived']

model = XGBClassifier(max_depth=2,
                     subsample=0.8,
                     n_estimators=200,
                     learning_rate=0.1,
                     min_child_weight=1,
                     reg_alpha=0,
                     reg_lambda=0.8
                     )

model.fit(X_train, y_train)
y_predict = model.predict(X_test)
output = pd.DataFrame({'PassengerId': raw_test_dataframe.PassengerId, 'Survived': y_predict})
output.to_csv('submission.csv', index=False)
# Out:
# [13:20:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# C:\Users\taspl\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# ...

# %%
raw_train_dataframe.loc[raw_train_dataframe.Parch >= 1]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 8              9         1       3
# 10            11         1       3
# 13            14         0       3
# 16            17         0       3
# ..           ...       ...     ...
# 871          872         1       1
# 879          880         1       1
# 880          881         1       2
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 16                                Rice, Master. Eugene    male   2.0      4
# ..                                                 ...     ...   ...    ...
# ...

# %%
raw_train_dataframe.loc[raw_train_dataframe.Parch >= 1].sort_values('Name')
# Out:
#      PassengerId  Survived  Pclass  \
# 746          747         0       3
# 279          280         1       3
# 855          856         1       3
# 305          306         1       1
# 297          298         0       1
# ..           ...       ...     ...
# 318          319         1       1
# 856          857         1       1
# 377          378         0       1
# 155          156         0       1
# 153          154         0       3
#
#                                            Name     Sex    Age  SibSp  Parch  \
# 746                 Abbott, Mr. Rossmore Edward    male  16.00      1      1
# 279            Abbott, Mrs. Stanton (Rosa Hunt)  female  35.00      1      1
# 855                  Aks, Mrs. Sam (Leah Rosen)  female  18.00      0      1
# 305              Allison, Master. Hudson Trevor    male   0.92      1      2
# 297                Allison, Miss. Helen Loraine  female   2.00      1      2
# ...

# %%
def get_title(name):
    title = ""
    name_list = name.split()
    for thing in name_list:
        if '.' in thing:
            title = thing

    title_dict = {
        'Mr.': 'Mr',
        'Mrs.': 'Mrs',
        'Miss.': 'Miss',
        'Master.': 'Master',
        'Don.': 'Noble',
        'Rev.': 'Noble',
        'Dr.': 'Noble',
        'Mme.': 'Mrs',
        'Ms.': 'Mrs',
        'Major.': 'Military',
        'L.': 'Military',
        'Lady.': 'Noble',
        'Sir.': 'Noble',
        'Mlle.': 'Miss',
        'Col.': 'Military',
        'Capt.': 'Military',
        'Countess.': 'Noble',
        'Jonkheer.': 'Noble',
        'Dona.': 'Noble'
        }

    return title_dict[title]

# %%
train_dataframe = raw_train_dataframe
test_dataframe = raw_test_dataframe
all_data = pd.concat([train_dataframe, test_dataframe])

for df in [train_dataframe, test_dataframe]:
    df['Title'] = df.Name.map(get_title)
    df['GroupSize'] = df['Ticket'].map(all_data['Ticket'].value_counts())
    df.Fare = df.Fare.fillna(30)
    df['FarePerPerson'] = df['Fare']/df['GroupSize']
    df.Age = df.Age.fillna(df.groupby(['Pclass', 'Parch', 'SibSp', 'Title']).Age.transform('median'))
    df.Embarked = df.Embarked.fillna('C')
    #df.Age = df.Age.fillna(df.Age.median())
    df['Age*Class'] = df['Age']*df['Pclass']

# %%
train_dataframe.loc[train_dataframe.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 159          160         0       3                Sage, Master. Thomas Henry
# 180          181         0       3              Sage, Miss. Constance Gladys
# 201          202         0       3                       Sage, Mr. Frederick
# 324          325         0       3                  Sage, Mr. George John Jr
# 792          793         0       3                   Sage, Miss. Stella Anna
# 846          847         0       3                  Sage, Mr. Douglas Bullen
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket   Fare Cabin Embarked   Title  \
# 159    male  NaN      8      2    CA. 2343  69.55   NaN        S  Master
# 180  female  NaN      8      2    CA. 2343  69.55   NaN        S    Miss
# ...

# %%
train_dataframe.Title.unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Noble', 'Military'], dtype=object)

# %%
train_dataframe.Title
# Out:
# 0         Mr
# 1        Mrs
# 2       Miss
# 3        Mrs
# 4         Mr
#        ...
# 886    Noble
# 887     Miss
# 888     Miss
# 889       Mr
# 890       Mr
# Name: Title, Length: 891, dtype: object

# %%
titles = ['Mr', 'Mrs', 'Miss', 'Master', 'Noble', 'Military']

total = 0
for title in titles:
    total_title = (train_dataframe.Title == title).sum()
    age_missing = ((train_dataframe.Title == title) & (train_dataframe.Age.isnull())).sum()
    title_mean = train_dataframe.loc[(train_dataframe.Title == title), 'Age'].mean()
    print("Number of ageless with title ", title, ": ", age_missing)
    print("Total number with title ", title, ": ", total_title)
    print("Average age of person with title ", title, ': ', title_mean)
    filt = ((train_dataframe.Title == title) & (train_dataframe.Age.isnull()))
    #train_dataframe.loc[filt, 'Age'] = train_dataframe.loc[(train_dataframe.Title == title), 'Age'].mean()

    filt2 = ((test_dataframe.Title == title) & (test_dataframe.Age.isnull()))
    #test_dataframe.loc[filt2, 'Age'] = test_dataframe.loc[(test_dataframe.Title == title), 'Age'].mean()
    total += age_missing

actual_total_missing_age = (train_dataframe.Age.isnull()).sum()
print("Summed missing ages across titles: ", total)
print("Total people with age missing: ", actual_total_missing_age)
# Out:
# Number of ageless with title  Mr. :  0
# Total number with title  Mr. :  517
# Average age of person with title  Mr. :  32.36809045226131
# Number of ageless with title  Mrs. :  0
# Total number with title  Mrs. :  124
# Average age of person with title  Mrs. :  35.728971962616825
# Number of ageless with title  Miss. :  0
# Total number with title  Miss. :  182
# Average age of person with title  Miss. :  21.773972602739725
# Number of ageless with title  Master. :  0
# Total number with title  Master. :  40
# Average age of person with title  Master. :  4.574166666666667
# Number of ageless with title  Don. :  0
# Total number with title  Don. :  1
# Average age of person with title  Don. :  40.0
# Number of ageless with title  Rev. :  0
# Total number with title  Rev. :  6
# Average age of person with title  Rev. :  43.166666666666664
# Number of ageless with title  Dr. :  0
# Total number with title  Dr. :  7
# Average age of person with title  Dr. :  42.0
# ...

# %%
# for df in [train_dataframe, test_dataframe]:
#     df.Age = df.Age.fillna(df.groupby(['Pclass', 'Parch', 'SibSp', 'Title']).Age.transform('median'))

# %%
features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Title']
X_train = pd.get_dummies(train_dataframe[features])
X_test = pd.get_dummies(test_dataframe[features])
y_train = train_dataframe['Survived']

model = XGBClassifier(max_depth=2,
                     subsample=0.8,
                     n_estimators=200,
                     learning_rate=0.1,
                     min_child_weight=1,
                     reg_alpha=0,
                     reg_lambda=0.8
                     )

model.fit(X_train, y_train)
y_predict = model.predict(X_test)
output = pd.DataFrame({'PassengerId': test_dataframe.PassengerId, 'Survived': y_predict})
output.to_csv('submission2.csv', index=False)
# Out:
# C:\Users\taspl\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Users\taspl\AppData\Local\Programs\Python\Python310\lib\site-packages\xgboost\data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# ...

# %%
features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Title', 'FarePerPerson', 'Age*Class']
X = pd.get_dummies(train_dataframe[features])
y = train_dataframe['Survived']

# %%
from sklearn.model_selection import train_test_split

X_train1,X_test1, y_train1,y_test1 = train_test_split(X,y,random_state=0,test_size=0.3)

# %%
X_train1.columns
# Out:
# Index(['Pclass', 'Age', 'SibSp', 'Parch', 'Sex_female', 'Sex_male',
#        'Title_Master', 'Title_Military', 'Title_Miss', 'Title_Mr', 'Title_Mrs',
#        'Title_Noble'],
#       dtype='object')

# %%
params = {
    "max_depth": [None],
    "max_features": [1, 3, 10],
    "min_samples_split": [2, 3, 10],
    "min_samples_leaf": [1, 3, 10],
    "bootstrap": [False],
    "n_estimators" :[100, 200, 300],
    "criterion": ["entropy"]
}

# %%
model = RandomForestClassifier()

# %%
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, GridSearchCV
from sklearn.metrics import roc_auc_score

# %%
features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Title', 'Embarked']
X_train = pd.get_dummies(train_dataframe[features])
X_test = pd.get_dummies(test_dataframe[features])
y_train = train_dataframe['Survived']

# %%
test_dataframe.loc[:, 'FarePerPerson'].isnull().sum()
# Out:
# 1

# %%
train_dataframe.Age.isnull().sum()
# Out:
# 8

# %%
k_fold = StratifiedKFold(n_splits=5)
gridcv = GridSearchCV(model, param_grid=params, cv=k_fold, scoring='accuracy', n_jobs=4, verbose=1)

gridcv.fit(X_train, y_train)

best_model = gridcv.best_estimator_
# Out:
# Fitting 5 folds for each of 81 candidates, totalling 405 fits

# %%
model1 = best_model

model1.fit(X_train, y_train)
y_predict = model1.predict(X_test)
output = pd.DataFrame({'PassengerId': test_dataframe.PassengerId, 'Survived': y_predict})
output.to_csv('submission2.csv', index=False)

# %%
folds = 3
param_comb = 5
skf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=1001)

random_search = RandomizedSearchCV(
    model, 
    param_distributions=params, 
    n_iter=param_comb, 
    scoring='roc_auc',
    n_jobs=4,
    cv=skf.split(X_train1, y_train1),
    verbose=3,
    random_state=1001
    )

random_search.fit(X_train1, y_train1)
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [05:45:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [05:45:58] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# ...

# %%
my_model = random_search.best_estimator_

my_model.fit(X_train1,y_train1)
y_predict1 = my_model.predict(X_test1)
from sklearn.metrics import accuracy_score, classification_report
print("Train accuracy: ", accuracy_score(y_train1, my_model.predict(X_train1)))
print("Test accuracy: ", accuracy_score(y_test1, y_predict1))
print(classification_report(y_test1, y_predict1))
pd.crosstab(y_test1, y_predict1)
# Out:
# [05:46:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:576:
# Parameters: { "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
#
#
# [05:46:14] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# Train accuracy:  0.8780096308186196
# Test accuracy:  0.8171641791044776
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       168
#            1       0.77      0.72      0.75       100
#
# ...

# %%
features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Title']
X_train = pd.get_dummies(train_dataframe[features])
X_test = pd.get_dummies(test_dataframe[features])
y_train = train_dataframe['Survived']

model1 = my_model

model1.fit(X_train, y_train)
y_predict = model1.predict(X_test)
output = pd.DataFrame({'PassengerId': test_dataframe.PassengerId, 'Survived': y_predict})
output.to_csv('submission2.csv', index=False)
